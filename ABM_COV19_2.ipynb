# %%
import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
gdf = ox.geometries.geometries_from_bbox(52.6500, 52.5900,-1.0500,-1.1600, tags = {'building':True})
gdf1 = ox.geometries.geometries_from_bbox(52.6500, 52.5900,-1.0500,-1.1600, tags = {'amenity':True})

# %%
lat_household=[]
long_household =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if(new_abc1['building'][i]=='yes'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_household.append(float(list1[0]))
        lat_household.append(float(list1[1]))
# Out:
# C:\Users\madhu\Anaconda3\envs\ox\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\madhu\Anaconda3\envs\ox\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (12,33,34,37,40,41,46,47,52,54,60,65,66,67,68,74,75,78,79,82,87,88,89,90,91,92,93,95,98,100,101,104,106,112,114,115,118,119,120,121,124,127,128,129,130,137,142,143,144,145,147,148,152,153,154,155,156,157,158,159,160,161,163,165,166,167,168,169,170,171,172,173,174,175,177,179,180,181,182,183,184,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
lat_restaurants=[]
long_restaurants =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if(new_abc1['amenity'][i]==''):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_restaurants.append(float(list1[0]))
        lat_restaurnats.append(float(list1[1]))
lat_restaurants=[]
long_restaurants =[]
new_abc2 = pd.read_csv('abc2.csv')
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='restaurant'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_restaurants.append(float(list1[0]))
        lat_restaurants.append(float(list1[1]))
lat_fast_food=[]
long_fast_food =[]
new_abc2 = pd.read_csv('abc2.csv')
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='fast_food'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_fast_food.append(float(list1[0]))
        lat_fast_food.append(float(list1[1]))
lat_pubs =[]
long_pubs =[]
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='pub'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_pubs.append(float(list1[0]))
        lat_pubs.append(float(list1[1]))
lat_hospitals =[]
long_hospitals =[]
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='hospital'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_hospitals.append(float(list1[0]))
        lat_hospitals.append(float(list1[1]))
len(lat_hospitals)
# Out:
# C:\Users\madhu\Anaconda3\envs\ox\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\madhu\Anaconda3\envs\ox\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (12,33,34,37,40,41,46,47,52,54,60,65,66,67,68,74,75,78,79,82,87,88,89,90,91,92,93,95,98,100,101,104,106,112,114,115,118,119,120,121,124,127,128,129,130,137,142,143,144,145,147,148,152,153,154,155,156,157,158,159,160,161,163,165,166,167,168,169,170,171,172,173,174,175,177,179,180,181,182,183,184,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 8

# %%
x_lat = np.zeros(shape =(5194))
x_long = np.zeros(shape =(5194))
for i in range(len(long_household)):
    x_long[i] = (float(long_household[i]) +1)
for i in range(len(long_household)):
    x_lat[i] = (float(lat_household[i]) -52)
x_lat1 = np.zeros(shape =(141))
x_long1 = np.zeros(shape =(141))
for i in range(len(long_restaurants)):
    x_long1[i] = (float(long_restaurants[i]) +1)
for i in range(len(long_restaurants)):
    x_lat1[i] = (float(lat_restaurants[i]) -52)
x_lat2 = np.zeros(shape =(160))
x_long2 = np.zeros(shape =(160))
for i in range(len(long_fast_food)):
    x_long2[i] = (float(long_fast_food[i]) +1)
for i in range(len(long_restaurants)):
    x_lat2[i] = (float(lat_fast_food[i]) -52)
x_lat3 = np.zeros(shape =(102))
x_long3 = np.zeros(shape =(102))
for i in range(len(long_pubs)):
    x_long3[i] = (float(long_pubs[i]) +1)
for i in range(len(long_pubs)):
    x_lat3[i] = (float(lat_pubs[i]) -52)
x_lat4 = np.zeros(shape =(8))
x_long4 = np.zeros(shape =(8))
for i in range(len(long_hospitals)):
    x_long4[i] = (float(long_hospitals[i]) +1)
for i in range(len(long_hospitals)):
    x_lat4[i] = (float(lat_hospitals[i]) -52)

# %%
from matplotlib.axis import Axis 
plt.figure(figsize=(20,20))
plt.plot(x_lat, x_long, '*', label = "households")
plt.plot(x_lat1, x_long1, '*', label ="restaurants")
plt.plot(x_lat2, x_long2, '*', label ="fast_food")
plt.plot(x_lat3, x_long3, '*', label ="pubs")
plt.plot(x_lat4, x_long4, '*', label ="hospitals")
plt.legend()
plt.xlim(0.58, 0.66)
plt.ylim(-0.04, -0.17)
# Out:
# (-0.04, -0.17)

# %%
long_household
# Out:
# [-1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
#  -1.0997227,
# ...
