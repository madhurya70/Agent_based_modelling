# %%
import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
gdf = ox.geometries.geometries_from_bbox(52.6500, 52.5900,-1.0500,-1.1600, tags = {'building':True})
gdf1 = ox.geometries.geometries_from_bbox(52.6500, 52.5900,-1.0500,-1.1600, tags = {'amenity':True})

# %%
## Extracting geographical coordinates for building types and organising them into a list for later use
lat_houses=[]
long_houses =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if( new_abc1['building'][i]=='yes' and new_abc1['name'][i]=='0'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_houses.append(float(list1[0]))
        lat_houses.append(float(list1[1]))
lat_apartments=[]
long_apartments =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if( new_abc1['building'][i]=='apartments' or new_abc1['building'][i]=='residential' or new_abc1['building'][i]=='house' or new_abc1['building'][i]=='terrace'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_apartments.append(float(list1[0]))
        lat_apartments.append(float(list1[1]))
lat_retail=[]
long_retail =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if(new_abc1['building'][i]=='retail' or new_abc1['building'][i]=='commercial'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_retail.append(float(list1[0]))
        lat_retail.append(float(list1[1]))
lat_offices=[]
long_offices =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if(new_abc1['building'][i]=='office' or new_abc1['building'][i]=='industrial' or new_abc1['building'][i]=='mill' ):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_offices.append(float(list1[0]))
        lat_offices.append(float(list1[1]))
lat_University=[]
long_University =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if(new_abc1['building'][i]=='university'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_University.append(float(list1[0]))
        lat_University.append(float(list1[1]))
lat_terrace=[]
long_terrace =[]
new_abc1 = pd.read_csv('abc1.csv')
for i in range(5194):
   if(new_abc1['building'][i]=='terrace'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_terrace.append(float(list1[0]))
        lat_terrace.append(float(list1[1]))

len(lat_apartments)
# Out:
# C:\Users\madhu\Anaconda3\envs\ox\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\madhu\Anaconda3\envs\ox\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (12,33,34,37,40,41,46,47,52,54,60,65,66,67,68,74,75,78,79,82,87,88,89,90,91,92,93,95,98,100,101,104,106,112,114,115,118,119,120,121,124,127,128,129,130,137,142,143,144,145,147,148,152,153,154,155,156,157,158,159,160,161,163,165,166,167,168,169,170,171,172,173,174,175,177,179,180,181,182,183,184,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 1071

# %%
## Extracting geographical coordinates for building types and organising them into a list for later use
lat_restaurants=[]
long_restaurants =[]
new_abc2 = pd.read_csv('abc2.csv')
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='restaurant' or new_abc2['amenity'][i]=='fast_food' or new_abc2['amenity'][i]=='pub' or new_abc2['amenity'][i]=='nightclub' or new_abc2['amenity'][i]=='cafe'):        
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_restaurants.append(float(list1[0]))
        lat_restaurants.append(float(list1[1]))

lat_hospitals =[]
long_hospitals =[]
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='hospital'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_hospitals.append(float(list1[0]))
        lat_hospitals.append(float(list1[1]))
lat_schools =[]
long_schools =[]
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='school' or new_abc2['amenity'][i]=='college'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_schools.append(float(list1[0]))
        lat_schools.append(float(list1[1]))
lat_worship =[]
long_worship =[]
for i in range(len(new_abc2['amenity'])):
   if(new_abc2['amenity'][i]=='church' or new_abc2['amenity'][i]=='place_of_worship'):
        x = new_abc1['geometry'][i]
        word = ""
        for e in x:
            word+= str(e)
        list1 =[]   
        list1 = word.split(",")  
        long_worship.append(float(list1[0]))
        lat_worship.append(float(list1[1]))
len(lat_restaurants)
# Out:
# 501

# %%
## Moving the extracted geographical information into numpy arrays
x_lat0 = np.zeros(shape =(2487))
x_long0 = np.zeros(shape =(2487))
for i in range(len(long_houses)):
    x_long0[i] = (float(long_houses[i]) +1)
for i in range(len(long_houses)):
    x_lat0[i] = (float(lat_houses[i]) -52)
x_lat = np.zeros(shape =(1071))
x_long = np.zeros(shape =(1071))
for i in range(len(long_apartments)):
    x_long[i] = (float(long_apartments[i]) +1)
for i in range(len(long_apartments)):
    x_lat[i] = (float(lat_apartments[i]) -52)
x_lat1 = np.zeros(shape =(501))
x_long1 = np.zeros(shape =(501))
for i in range(len(long_restaurants)):
    x_long1[i] = (float(long_restaurants[i]) +1)
for i in range(len(long_restaurants)):
    x_lat1[i] = (float(lat_restaurants[i]) -52)
x_lat4 = np.zeros(shape =(8))
x_long4 = np.zeros(shape =(8))
for i in range(len(long_hospitals)):
    x_long4[i] = (float(long_hospitals[i]) +1)
for i in range(len(long_hospitals)):
    x_lat4[i] = (float(lat_hospitals[i]) -52)
x_lat5 = np.zeros(shape =(208))
x_long5 = np.zeros(shape =(208))
for i in range(len(long_retail)):
    x_long5[i] = (float(long_retail[i]) +1)
for i in range(len(long_retail)):
    x_lat5[i] = (float(lat_retail[i]) -52)
x_lat6 = np.zeros(shape =(307))
x_long6 = np.zeros(shape =(307))
for i in range(len(long_offices)):
    x_long6[i] = (float(long_offices[i]) +1)
for i in range(len(long_offices)):
    x_lat6[i] = (float(lat_offices[i]) -52)
x_lat7 = np.zeros(shape =(307))
x_long7 = np.zeros(shape =(307))
for i in range(len(long_University)):
    x_long7[i] = (float(long_University[i]) +1)
for i in range(len(long_University)):
    x_lat7[i] = (float(lat_University[i]) -52)
x_lat8 = np.zeros(shape =(93))
x_long8 = np.zeros(shape =(93))
for i in range(len(long_schools)):
    x_long8[i] = (float(long_schools[i]) +1)
for i in range(len(long_schools)):
    x_lat8[i] = (float(lat_schools[i]) -52)
x_lat9 = np.zeros(shape =(181))
x_long9 = np.zeros(shape =(181))
for i in range(len(long_worship)):
    x_long9[i] = (float(long_worship[i]) +1)
for i in range(len(long_worship)):
    x_lat9[i] = (float(lat_worship[i]) -52)

# %%
##Plotting the extracted geographical information
from matplotlib.axis import Axis 
plt.figure(figsize=(20,20))
plt.plot(x_lat0, x_long0, '*', label = "houses")
plt.plot(x_lat, x_long, '*', label = "apartments")
plt.plot(x_lat1, x_long1, '*', label ="restaurants/fast_food")
plt.plot(x_lat4, x_long4, '*', label ="hospitals")
plt.plot(x_lat5, x_long5, '*', label ="retail/commercial")
plt.plot(x_lat6, x_long6, '*', label ="office/industrial/mill")
plt.plot(x_lat7, x_long7, '*', label ="Univesity")
plt.plot(x_lat8, x_long8, '*', label ="Schools/colleges")
plt.plot(x_lat9, x_long9, '*', label ="places of worship")
plt.legend()
plt.xlim(0.58, 0.66)
plt.ylim(-0.04, -0.17)
# Out:
# (-0.04, -0.17)

# %%
##Code for initializing agents based on their age group, employement and family status , and environment, where an agent's environment depends on the agent's current location.
import numpy as np
class person:
    def __init__(self, age_group, employed, family, env ):
        self.age_group = age_group
        self.employed = employed
        self.family =family
        self.env = env

# %%
##Creating a discrete probability distribution for the age distribution 
age_distribution =[]
elements =[1,2,4,5]
probabilities =[0.5, 0.15, 25, 0.1]
age_distribution = np.random.choice(elements, 1000, probabilities)
